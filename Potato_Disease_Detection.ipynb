# %% [markdown]
# <a href="https://colab.research.google.com/github/EhtashamulHaque/Potato-Leaf-Disease-Detection-using-Deep-Learning/blob/main/Potato_Disease_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import keras
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pathlib
import seaborn as sns
import tensorflow as tf
import tensorflow_addons as tfa

from keras.utils import plot_model
from imblearn.over_sampling import SMOTE
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import BatchNormalization, Conv2D, Conv2DTranspose, Dense, Dropout, Flatten, GlobalAveragePooling2D, Input, MaxPooling2D
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_curve, roc_auc_score
from tensorflow.keras.applications import ResNet50V2, VGG16, InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from keras.utils import load_img,img_to_array

# %%
folder = '/content/drive/MyDrive/plant Village/PlantVillage'

# %%
photo = load_img('/content/drive/MyDrive/plant Village/PlantVillage/Potato___Early_blight/009c8c31-f22d-4ffd-8f16-189c6f06c577___RS_Early.B 7885.JPG')
print(photo)
photo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7EBC4896EA40>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
IMG_SIZE = 128
DIM = (IMG_SIZE, IMG_SIZE)

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

# %%
train_generator = ImageDataGenerator(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM,
                                     data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)
train_data_gen = train_generator.flow_from_directory(directory=folder, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
train_data, train_labels = train_data_gen.next()

# %%
#Synthetic Minority Over-sampling Technique
sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

print(train_data.shape, train_labels.shape)
# Out:
# (2000, 49152) (2000, 1)

# %%
train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (2000, 128, 128, 3) (2000, 1)

# %%
train_labels = train_labels.reshape(-1, 1)

# %%
for i in range(2):
    plt.subplot(2,2,1+i)
    plt.title(train_labels[i])
    plt.imshow(train_data[i])

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_labels,test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

train_data, val_data, train_labels,val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
from keras.layers import MaxPool2D


act = 'relu'
IMAGE_SIZE = (128, 128)

cnn_model = Sequential([
Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
Conv2D(16, 3, activation=act, padding='same'),
Conv2D(16, 3, activation=act, padding='same'),
BatchNormalization(),
MaxPool2D(),
Conv2D(32, 3, activation=act, padding='same'),
Conv2D(32, 3, activation=act, padding='same'),
BatchNormalization(),
MaxPool2D(),
Conv2D(64, 3, activation=act, padding='same'),
Conv2D(64, 3, activation=act, padding='same'),
Conv2D(64, 3, activation=act, padding='same'),
BatchNormalization(),
MaxPool2D(),
Dropout(0.2),
Conv2D(128, 3, activation=act, padding='same'),
Conv2D(128, 3, activation=act, padding='same'),
Conv2D(128, 3, activation=act, padding='same'),
BatchNormalization(),
    MaxPool2D(),
Dropout(0.2),
Conv2D(256, 3, activation=act, padding='same'),
Conv2D(256, 3, activation=act, padding='same'),
Conv2D(256, 3, activation=act, padding='same'),
BatchNormalization(),
MaxPool2D(),
Dropout(0.2),
Flatten(),
Dense(512, activation=act),
BatchNormalization(),
Dropout(0.7),
Dense(128, activation=act),
BatchNormalization(),
Dropout(0.5),
Dense(64, activation=act),
BatchNormalization(),
Dropout(0.3),
Dense(1, activation='sigmoid')
], name='cnn_model')

# %%
# Compile the model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

cnn_model.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      2320
#
#  batch_normalization (Batch  (None, 128, 128, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 64, 64, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        36928
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       147584
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)         295168
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 256)         590080
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  batch_normalization_6 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4129809 (15.75 MB)
# Trainable params: 4127409 (15.74 MB)
# Non-trainable params: 2400 (9.38 KB)
# _________________________________________________________________

# %%
tf.keras.backend.set_image_data_format('channels_first')

# %%
# Fit the model to the training data
history = cnn_model.fit(train_data, train_labels, epochs=50, verbose=1)

# Store accuracy and loss history for each epoch
cnn_accuracy_history = history.history['accuracy']
cnn_loss_history = history.history['loss']
# Out:
# Epoch 1/50
# 40/40 [==============================] - 17s 44ms/step - loss: 0.5702 - accuracy: 0.7297
# Epoch 2/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.3630 - accuracy: 0.8508
# Epoch 3/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.2574 - accuracy: 0.8969
# Epoch 4/50
# 40/40 [==============================] - 2s 41ms/step - loss: 0.1642 - accuracy: 0.9312
# Epoch 5/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.1111 - accuracy: 0.9594
# Epoch 6/50
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0879 - accuracy: 0.9734
# Epoch 7/50
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0990 - accuracy: 0.9625
# Epoch 8/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0545 - accuracy: 0.9852
# Epoch 9/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0883 - accuracy: 0.9695
# Epoch 10/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0772 - accuracy: 0.9711
# Epoch 11/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0569 - accuracy: 0.9812
# Epoch 12/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0524 - accuracy: 0.9797
# Epoch 13/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0742 - accuracy: 0.9727
# Epoch 14/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0706 - accuracy: 0.9766
# Epoch 15/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0614 - accuracy: 0.9789
# Epoch 16/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0627 - accuracy: 0.9805
# Epoch 17/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0730 - accuracy: 0.9766
# Epoch 18/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0869 - accuracy: 0.9688
# Epoch 19/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0770 - accuracy: 0.9703
# Epoch 20/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0895 - accuracy: 0.9672
# Epoch 21/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0895 - accuracy: 0.9680
# Epoch 22/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0775 - accuracy: 0.9727
# Epoch 23/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0733 - accuracy: 0.9789
# Epoch 24/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0382 - accuracy: 0.9883
# Epoch 25/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0464 - accuracy: 0.9844
# Epoch 26/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0355 - accuracy: 0.9875
# Epoch 27/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0566 - accuracy: 0.9812
# Epoch 28/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0509 - accuracy: 0.9844
# Epoch 29/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0329 - accuracy: 0.9891
# Epoch 30/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0327 - accuracy: 0.9875
# Epoch 31/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0705 - accuracy: 0.9758
# Epoch 32/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0583 - accuracy: 0.9805
# Epoch 33/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0572 - accuracy: 0.9828
# Epoch 34/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0279 - accuracy: 0.9937
# Epoch 35/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0194 - accuracy: 0.9922
# Epoch 36/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0251 - accuracy: 0.9937
# Epoch 37/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0167 - accuracy: 0.9953
# Epoch 38/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0315 - accuracy: 0.9906
# Epoch 39/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0641 - accuracy: 0.9773
# Epoch 40/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0591 - accuracy: 0.9812
# Epoch 41/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0695 - accuracy: 0.9789
# Epoch 42/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0643 - accuracy: 0.9742
# Epoch 43/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0749 - accuracy: 0.9734
# Epoch 44/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0456 - accuracy: 0.9867
# Epoch 45/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0332 - accuracy: 0.9898
# Epoch 46/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0429 - accuracy: 0.9867
# Epoch 47/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0175 - accuracy: 0.9937
# Epoch 48/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0322 - accuracy: 0.9859
# Epoch 49/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0412 - accuracy: 0.9914
# Epoch 50/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0331 - accuracy: 0.9875

# %%
loss, accuracy = cnn_model.evaluate(test_data, test_labels)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# 13/13 [==============================] - 1s 61ms/step - loss: 0.1286 - accuracy: 0.9450
# Accuracy: 94.50%

# %%
y_pred = np.round(cnn_model.predict(test_data)).astype(int)

target_names = ['Potato___Early_blight', 'Potato___Late_blight']
report = classification_report(test_labels, y_pred, target_names=target_names, output_dict=True)

for target_name in target_names:
    precision = report[target_name]['precision']
    recall = report[target_name]['recall']
    f1_score = report[target_name]['f1-score']

# Average precision, recall, and F1-score
avg_precision = report['weighted avg']['precision']
avg_recall = report['weighted avg']['recall']
avg_f1_score = report['weighted avg']['f1-score']

print('Average Precision: {:.2f}%'.format(avg_precision*100))
print('Average Recall: {:.2f}%'.format(avg_recall*100))
print('Average F1 Score: {:.2f}%'.format(avg_f1_score*100))

cnn_precision = avg_precision
cnn_recall = avg_recall
cnn_f1score = avg_f1_score
# Out:
# 13/13 [==============================] - 1s 11ms/step
# Average Precision: 94.95%
# Average Recall: 94.50%
# Average F1 Score: 94.48%

# %%
# Get predicted probabilities for test set
y_pred_prob = cnn_model.predict(test_data)

# Get false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(test_labels, y_pred_prob)

# Compute AUC score
roc_auc = roc_auc_score(test_labels, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(4,3))
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 13/13 [==============================] - 0s 10ms/step

# %%
y_scores = cnn_model.predict(test_data)
precision, recall, _ = precision_recall_curve(test_labels, y_scores)

plt.figure(figsize=(4,3)) # set figure size
plt.plot(recall, precision, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
# Out:
# 13/13 [==============================] - 0s 13ms/step

# %%
# your code here
cm = confusion_matrix(test_labels, y_pred)
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from keras import backend as K

K.set_image_data_format('channels_last')
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
for layer in vgg_model.layers:
    layer.trainable = False

# %%
vgg16_model = Sequential([
    vgg_model,
    Flatten(),
    BatchNormalization(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    BatchNormalization(),
    Dense(1, activation='sigmoid')
], name="vgg16_model")

# %%
vgg16_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
vgg16_model.summary()
# Out:
# Model: "vgg16_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  batch_normalization_8 (Bat  (None, 8192)              32768
#  chNormalization)
#
#  dense_4 (Dense)             (None, 512)               4194816
#
#  batch_normalization_9 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  batch_normalization_10 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  batch_normalization_11 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  batch_normalization_12 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 19118657 (72.93 MB)
# Trainable params: 4385665 (16.73 MB)
# Non-trainable params: 14732992 (56.20 MB)
# _________________________________________________________________

# %%
plot_model(vgg16_model)

# %%
# Fit the model to the training data
vgg16_history = vgg16_model.fit(train_data, train_labels, epochs=50, verbose=1)

# Store accuracy and loss history for each epoch
vgg16_accuracy_history = vgg16_history.history['accuracy']
vgg16_loss_history = vgg16_history.history['loss']
# Out:
# Epoch 1/50
# 40/40 [==============================] - 8s 43ms/step - loss: 0.5631 - accuracy: 0.7195
# Epoch 2/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.3219 - accuracy: 0.8703
# Epoch 3/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.1908 - accuracy: 0.9281
# Epoch 4/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.1562 - accuracy: 0.9484
# Epoch 5/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.1345 - accuracy: 0.9508
# Epoch 6/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.1025 - accuracy: 0.9641
# Epoch 7/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0846 - accuracy: 0.9719
# Epoch 8/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0646 - accuracy: 0.9789
# Epoch 9/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0505 - accuracy: 0.9852
# Epoch 10/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0440 - accuracy: 0.9891
# Epoch 11/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0519 - accuracy: 0.9852
# Epoch 12/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0397 - accuracy: 0.9883
# Epoch 13/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0613 - accuracy: 0.9805
# Epoch 14/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0550 - accuracy: 0.9797
# Epoch 15/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0512 - accuracy: 0.9836
# Epoch 16/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0386 - accuracy: 0.9875
# Epoch 17/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0442 - accuracy: 0.9844
# Epoch 18/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0560 - accuracy: 0.9797
# Epoch 19/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0347 - accuracy: 0.9883
# Epoch 20/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0494 - accuracy: 0.9797
# Epoch 21/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0278 - accuracy: 0.9937
# Epoch 22/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0317 - accuracy: 0.9914
# Epoch 23/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0342 - accuracy: 0.9883
# Epoch 24/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0253 - accuracy: 0.9930
# Epoch 25/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0281 - accuracy: 0.9945
# Epoch 26/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0472 - accuracy: 0.9844
# Epoch 27/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0321 - accuracy: 0.9914
# Epoch 28/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0398 - accuracy: 0.9891
# Epoch 29/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0405 - accuracy: 0.9867
# Epoch 30/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0298 - accuracy: 0.9898
# Epoch 31/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0416 - accuracy: 0.9844
# Epoch 32/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0268 - accuracy: 0.9898
# Epoch 33/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0380 - accuracy: 0.9875
# Epoch 34/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0156 - accuracy: 0.9945
# Epoch 35/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0397 - accuracy: 0.9875
# Epoch 36/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0399 - accuracy: 0.9883
# Epoch 37/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0352 - accuracy: 0.9891
# Epoch 38/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0228 - accuracy: 0.9922
# Epoch 39/50
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0350 - accuracy: 0.9914
# Epoch 40/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0262 - accuracy: 0.9945
# Epoch 41/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0299 - accuracy: 0.9883
# Epoch 42/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0339 - accuracy: 0.9898
# Epoch 43/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0259 - accuracy: 0.9922
# Epoch 44/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0261 - accuracy: 0.9930
# Epoch 45/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0218 - accuracy: 0.9922
# Epoch 46/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0580 - accuracy: 0.9812
# Epoch 47/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0135 - accuracy: 0.9945
# Epoch 48/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0184 - accuracy: 0.9930
# Epoch 49/50
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0222 - accuracy: 0.9930
# Epoch 50/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0407 - accuracy: 0.9875

# %%
loss, accuracy = vgg16_model.evaluate(test_data, test_labels)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# 13/13 [==============================] - 3s 188ms/step - loss: 0.2236 - accuracy: 0.9425
# Accuracy: 94.25%

# %%
y_pred = np.round(vgg16_model.predict(test_data)).astype(int)

target_names = ['Potato___Early_blight', 'Potato___Late_blight']
report = classification_report(test_labels, y_pred, target_names=target_names, output_dict=True)

for target_name in target_names:
    precision = report[target_name]['precision']
    recall = report[target_name]['recall']
    f1_score = report[target_name]['f1-score']

# Average precision, recall, and F1-score
avg_precision = report['weighted avg']['precision']
avg_recall = report['weighted avg']['recall']
avg_f1_score = report['weighted avg']['f1-score']

print('Average Precision: {:.2f}%'.format(avg_precision*100))
print('Average Recall: {:.2f}%'.format(avg_recall*100))
print('Average F1 Score: {:.2f}%'.format(avg_f1_score*100))

vgg16_precision = avg_precision
vgg16_recall = avg_recall
vgg16_f1score = avg_f1_score
# Out:
# 13/13 [==============================] - 1s 39ms/step
# Average Precision: 94.26%
# Average Recall: 94.25%
# Average F1 Score: 94.25%

# %%
# Get predicted probabilities for test set
y_pred_prob_tl = vgg16_model.predict(test_data)

# Get false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(test_labels, y_pred_prob_tl)

# Compute AUC score
roc_auc = roc_auc_score(test_labels, y_pred_prob_tl)

# Plot ROC curve
plt.figure(figsize=(4,3))
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 13/13 [==============================] - 1s 40ms/step

# %%
y_scores = vgg16_model.predict(test_data)
precision, recall, _ = precision_recall_curve(test_labels, y_scores)

plt.figure(figsize=(4,3)) # set figure size
plt.plot(recall, precision, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
# Out:
# 13/13 [==============================] - 0s 39ms/step

# %%
# Load the pre-trained ResNet50V2 model
resnet50v2 = ResNet50V2(include_top=False, weights='imagenet', input_shape=(128, 128, 3))

# Freeze the layers in the pre-trained model
for layer in resnet50v2.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 0s 0us/step

# %%
ResNet50V2_model = Sequential([
    resnet50v2,
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
], name="ResNet50V2_model")

# %%
ResNet50V2_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

ResNet50V2_model.summary()
# Out:
# Model: "ResNet50V2_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 4, 4, 2048)        23564800
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dense_9 (Dense)             (None, 512)               16777728
#
#  batch_normalization_13 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  batch_normalization_14 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 40477185 (154.41 MB)
# Trainable params: 16910849 (64.51 MB)
# Non-trainable params: 23566336 (89.90 MB)
# _________________________________________________________________

# %%
plot_model(ResNet50V2_model)

# %%
ResNet50V2_model_history = ResNet50V2_model.fit(train_data, train_labels, epochs=50, verbose=1)

# Store accuracy and loss history for each epoch
ResNet_accuracy_history = ResNet50V2_model_history.history['accuracy']
ResNet_loss_history = ResNet50V2_model_history.history['loss']
# Out:
# Epoch 1/50
# 40/40 [==============================] - 8s 37ms/step - loss: 0.2775 - accuracy: 0.8961
# Epoch 2/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.1119 - accuracy: 0.9602
# Epoch 3/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0697 - accuracy: 0.9703
# Epoch 4/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0432 - accuracy: 0.9844
# Epoch 5/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0209 - accuracy: 0.9953
# Epoch 6/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0286 - accuracy: 0.9914
# Epoch 7/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0227 - accuracy: 0.9891
# Epoch 8/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0228 - accuracy: 0.9906
# Epoch 9/50
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0288 - accuracy: 0.9914
# Epoch 10/50
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0146 - accuracy: 0.9969
# Epoch 11/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0161 - accuracy: 0.9945
# Epoch 12/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0112 - accuracy: 0.9953
# Epoch 13/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0082 - accuracy: 0.9969
# Epoch 14/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0088 - accuracy: 0.9977
# Epoch 15/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0121 - accuracy: 0.9953
# Epoch 16/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0118 - accuracy: 0.9961
# Epoch 17/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0115 - accuracy: 0.9961
# Epoch 18/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0118 - accuracy: 0.9969
# Epoch 19/50
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0125 - accuracy: 0.9961
# Epoch 20/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0183 - accuracy: 0.9922
# Epoch 21/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0060 - accuracy: 0.9984
# Epoch 22/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0077 - accuracy: 0.9977
# Epoch 23/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0052 - accuracy: 0.9977
# Epoch 24/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0033 - accuracy: 0.9984
# Epoch 25/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 26/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 27/50
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0340 - accuracy: 0.9883
# Epoch 28/50
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0154 - accuracy: 0.9945
# Epoch 29/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0070 - accuracy: 0.9984
# Epoch 30/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 31/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 32/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0078 - accuracy: 0.9984
# Epoch 33/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0061 - accuracy: 0.9969
# Epoch 34/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 35/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 36/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0492 - accuracy: 0.9883
# Epoch 37/50
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0364 - accuracy: 0.9883
# Epoch 38/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0098 - accuracy: 0.9977
# Epoch 39/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0144 - accuracy: 0.9937
# Epoch 40/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0145 - accuracy: 0.9937
# Epoch 41/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0140 - accuracy: 0.9930
# Epoch 42/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0117 - accuracy: 0.9937
# Epoch 43/50
# 40/40 [==============================] - 2s 39ms/step - loss: 0.0096 - accuracy: 0.9953
# Epoch 44/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0089 - accuracy: 0.9969
# Epoch 45/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 46/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0057 - accuracy: 0.9992
# Epoch 47/50
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 48/50
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 49/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0083 - accuracy: 0.9984
# Epoch 50/50
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0019 - accuracy: 1.0000

# %%
loss, accuracy = ResNet50V2_model.evaluate(test_data, test_labels)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# 13/13 [==============================] - 3s 131ms/step - loss: 0.1457 - accuracy: 0.9650
# Accuracy: 96.50%

# %%
y_pred = np.round(ResNet50V2_model.predict(test_data)).astype(int)

target_names = ['Potato___Early_blight', 'Potato___Late_blight']
report = classification_report(test_labels, y_pred, target_names=target_names, output_dict=True)

for target_name in target_names:
    precision = report[target_name]['precision']
    recall = report[target_name]['recall']
    f1_score = report[target_name]['f1-score']

# Average precision, recall, and F1-score
avg_precision = report['weighted avg']['precision']
avg_recall = report['weighted avg']['recall']
avg_f1_score = report['weighted avg']['f1-score']

print('Average Precision: {:.2f}%'.format(avg_precision*100))
print('Average Recall: {:.2f}%'.format(avg_recall*100))
print('Average F1 Score: {:.2f}%'.format(avg_f1_score*100))

ResNet_precision = avg_precision
ResNet_recall = avg_recall
ResNet_f1score = avg_f1_score
# Out:
# 13/13 [==============================] - 1s 35ms/step
# Average Precision: 96.52%
# Average Recall: 96.50%
# Average F1 Score: 96.50%

# %%
# Get predicted probabilities for test set
y_pred = ResNet50V2_model.predict(test_data)

fpr, tpr, thresholds = roc_curve(test_labels, y_pred_prob)
roc_auc = roc_auc_score(test_labels, y_pred_prob)
plt.figure(figsize=(4,3))
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 13/13 [==============================] - 0s 30ms/step

# %%
y_scores = ResNet50V2_model.predict(test_data)
precision, recall, _ = precision_recall_curve(test_labels, y_scores)

plt.figure(figsize=(4,3)) # set figure size
plt.plot(recall, precision, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
# Out:
# 13/13 [==============================] - 0s 31ms/step

# %%
# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(test_data, test_labels)

# Evaluate the VGG16 model
vgg16_loss, vgg16_accuracy = vgg16_model.evaluate(test_data, test_labels)

# Evaluate the ResNet50V2 model
resnet_loss, resnet_accuracy = ResNet50V2_model.evaluate(test_data, test_labels)

print('+-------------------------------------------------------+')
print('|{"Model Evaluation Results"} |   {"loss"} | {"accuracy"}             |')
print('+-----------------+---------------+---------------------+')
print(f'|    {"CNN Model":<15} |    {cnn_loss:.2f}      |        {cnn_accuracy:.2f}        |')
print('+-----------------+---------------+---------------------+')


print(f'|   {"VGG16 Model":<15} |    {vgg16_loss:.2f}      |        {vgg16_accuracy:.2f}        |')
print('+-----------------+---------------+---------------------+')


print(f'| {"ResNet50V2 Model":<15} |    {resnet_loss:.2f}      |        {resnet_accuracy:.2f}         |')
print('+-----------------+---------------+---------------------+')
# Out:
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1286 - accuracy: 0.9450
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2236 - accuracy: 0.9425
# 13/13 [==============================] - 0s 33ms/step - loss: 0.1457 - accuracy: 0.9650
# +-------------------------------------------------------+
# |{"Model Evaluation Results"} |   {"loss"} | {"accuracy"}             |
# +-----------------+---------------+---------------------+
# |    CNN Model       |    0.13      |        0.94        |
# +-----------------+---------------+---------------------+
# |   VGG16 Model     |    0.22      |        0.94        |
# +-----------------+---------------+---------------------+
# | ResNet50V2 Model |    0.15      |        0.96         |
# +-----------------+---------------+---------------------+

# %%
# Extract the accuracy history for each model every 5 epochs
cnn_history = cnn_accuracy_history[::5]
vgg16_history = vgg16_accuracy_history[::5]
resnet_history = ResNet_accuracy_history[::5]

# Plot the accuracy history for each model
plt.plot(cnn_history, label='CNN')
plt.plot(vgg16_history, label='VGG16')
plt.plot(resnet_history, label='ResNet50V2')

# Set the plot title and axis labels
plt.title('Training Accuracy by Epoch (Every 5 Epochs)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()

# %%
# Extract the loss history for each model every 5 epochs
cnn_history = cnn_loss_history[::5]
vgg16_history = vgg16_loss_history[::5]
resnet_history = ResNet_loss_history[::5]

# Plot the loss history for each model
plt.plot(cnn_history, label='CNN')
plt.plot(vgg16_history, label='VGG16')
plt.plot(resnet_history, label='ResNet50V2')

# Set the plot title and axis labels
plt.title('Training Loss by Epoch (Every 5 Epochs)')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()

# %%
# Create a dictionary to store the metrics
metrics_dict = {
    'Model': ['CNN', 'VGG16', 'ResNet50V2'],
   'Avg Precision': [cnn_precision*100, vgg16_precision*100, ResNet_precision*100],
        'Avg Recall': [cnn_recall*100, vgg16_recall*100, ResNet_recall*100],
        'Avg F1-Score': [cnn_f1score*100, vgg16_f1score*100, ResNet_f1score*100]
}

# Create a pandas DataFrame from the dictionary
metrics_df = pd.DataFrame(metrics_dict)

# Print the DataFrame
print(metrics_df)
# Out:
#         Model  Avg Precision  Avg Recall  Avg F1-Score
# 0         CNN      94.947180       94.50     94.484829
# 1       VGG16      94.259529       94.25     94.249461
# 2  ResNet50V2      96.518261       96.50     96.499475
